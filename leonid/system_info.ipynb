# %%
# !hostname
# !nvidia-smi
# !lscpu | grep 'Model name'
# !free -h
# Out:
# falcon2
# Sat Nov  8 09:42:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-PCIE-32GB           Off |   00000000:85:00.0 Off |                    0 |
# | N/A   46C    P0             29W /  250W |       1MiB /  32768MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Model name:                         Intel(R) Xeon(R) CPU E5-2650 v4 @ 2.20GHz
#                total        used        free      shared  buff/cache   available
# Mem:           503Gi        38Gi       463Gi       6.8Gi        11Gi       464Gi
# Swap:          4.0Gi          0B       4.0Gi
# Requirement already satisfied: torch in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (2.8.0)
# Requirement already satisfied: torchvision in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (0.23.0)
# Requirement already satisfied: filelock in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torch) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from triton==3.4.0->torch) (53.0.0)
# Requirement already satisfied: importlib-metadata in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from triton==3.4.0->torch) (8.7.0)
# Requirement already satisfied: numpy in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /gpfs/helios/home/leonid98/.env/lib/python3.9/site-packages (from jinja2->torch) (3.0.3)

# %%
import sys, platform
print("Python:", platform.python_version())
print("Executable:", sys.executable)
# Out:
# Python: 3.9.18
# Executable: /gpfs/helios/home/leonid98/.env/bin/python3

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Device count:", torch.cuda.device_count())
    print("Current device:", torch.cuda.current_device())
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.8.0+cu128
# CUDA available: True
# Device count: 1
# Current device: 0
# GPU name: Tesla V100-PCIE-32GB

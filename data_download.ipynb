# %%
# !pip install kaggle

# %% [markdown]
# ### NOTE:
#
# If you see error 401: Unauthorized key, just regeneratge your api key in the https://www.kaggle.com/settings

# %%
# !kaggle competitions download -c predict-energy-behavior-of-prosumers
# Out:
# ...
#  80%|████████████████████████████████▏       | 187M/233M [00:00<00:00, 1.96GB/s]
# 100%|████████████████████████████████████████| 233M/233M [00:00<00:00, 1.95GB/s]

# %% [markdown]
# ### NOTE:
#
# Do not put data in git repo. As per user agreement, this data is avaiable only for competition participants

# %%
# !mv predict-energy-behavior-of-prosumers.zip data/
# !unzip data/predict-energy-behavior-of-prosumers.zip -d data/
# !rm data/predict-energy-behavior-of-prosumers.zip
# Out:
# mv: cannot stat 'predict-energy-behavior-of-prosumers.zip': No such file or directory
# Archive:  data/predict-energy-behavior-of-prosumers.zip
#   inflating: data/client.csv
#   inflating: data/county_id_to_name_map.json
#   inflating: data/electricity_prices.csv
#   inflating: data/enefit/__init__.py
#   inflating: data/enefit/competition.cpython-310-x86_64-linux-gnu.so
#   inflating: data/example_test_files/client.csv
#   inflating: data/example_test_files/electricity_prices.csv
#   inflating: data/example_test_files/forecast_weather.csv
#   inflating: data/example_test_files/gas_prices.csv
#   inflating: data/example_test_files/historical_weather.csv
#   inflating: data/example_test_files/revealed_targets.csv
#   inflating: data/example_test_files/sample_submission.csv
#   inflating: data/example_test_files/test.csv
#   inflating: data/forecast_weather.csv
#   inflating: data/gas_prices.csv
#   inflating: data/historical_weather.csv
# ...

# %%
# !kaggle competitions submit -c predict-energy-behavior-of-prosumers -f sample_submission.csv -m "Test submission"
# Out:
# 100%|█████████████████████████████████████████| 122k/122k [00:00<00:00, 168kB/s]
# 400 Client Error: Bad Request for url: https://www.kaggle.com/api/v1/competitions/submissions/submit/predict-energy-behavior-of-prosumers

# %% [markdown]
# ---

# %%
# !kaggle competitions download -c china-real-estate-demand-prediction
# Out:
# ...
#   0%|                                                | 0.00/670k [00:00<?, ?B/s]
# 100%|█████████████████████████████████████████| 670k/670k [00:00<00:00, 244MB/s]

# %%
# !mkdir data
# !mv china-real-estate-demand-prediction.zip data/
# !unzip data/china-real-estate-demand-prediction.zip -d data/
# !rm data/china-real-estate-demand-prediction.zip
# Out:
# Archive:  data/china-real-estate-demand-prediction.zip
#   inflating: data/sample_submission.csv
#   inflating: data/test.csv
#   inflating: data/train/city_indexes.csv
#   inflating: data/train/city_search_index.csv
#   inflating: data/train/land_transactions.csv
#   inflating: data/train/land_transactions_nearby_sectors.csv
#   inflating: data/train/new_house_transactions.csv
#   inflating: data/train/new_house_transactions_nearby_sectors.csv
#   inflating: data/train/pre_owned_house_transactions.csv
#   inflating: data/train/pre_owned_house_transactions_nearby_sectors.csv
#   inflating: data/train/sector_POI.csv

# %%
kaggle competitions submit -c china-real-estate-demand-prediction -f data/sample_submission.csv -m "Sample submission"
